# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm  key   mode  \
# ...

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    int64
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    float64
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# ## Finding inconsistent data by checking:
# Data types, Missing values, Outliers, Regular expression checks,
# Domain specific checks, visual inspection

# %% [markdown]
# ### CHANGING DATA TYPES

# %%
#Checking DATA TYPES
print("Before conversion:")
print(df.dtypes)
# Out:
# Before conversion:
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                  object
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists       int64
# in_deezer_charts          int64
# in_shazam_charts        float64
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object

# %%
# Convert 'streams', 'in_shazam_charts','in_deezer_playlists'   from object to integer, handling errors by setting invalid values to NaN
df['streams'] = pd.to_numeric(df['streams'], errors='coerce').astype('Int64')
df['in_shazam_charts'] = pd.to_numeric(df['in_shazam_charts'], errors='coerce').astype('Int64')

# Display the DataFrame after conversion
print("After Conversion:")
print(df.dtypes)
# Out:
# After Conversion:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                  Int64
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists      int64
# in_deezer_charts         int64
# in_shazam_charts         Int64
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
#finding MISSING VALUES
missing_values = df.isnull()
missing_count = missing_values.sum()
print(missing_count)
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  1
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
#fixing inconsistencies in column - in_deezer_playlists:
#removing commas from object values and turning them into integers
missing_values_count = df['in_deezer_playlists'].isna().sum()
print(f"Missing Values in '{'in_deezer_playlists'}': {missing_values_count}")
# Out:
# Missing Values in 'in_deezer_playlists': 0

# %%
row_index = 48  
print("Row at index", row_index, df.iloc[row_index])
# Out:
# Row at index 48 track_name                            Starboy
# artist(s)_name          The Weeknd, Daft Punk
# artist_count                                2
# released_year                            2016
# released_month                              9
# released_day                               21
# in_spotify_playlists                    29536
# in_spotify_charts                          79
# streams                            2565529693
# in_apple_playlists                        281
# in_apple_charts                           137
# in_deezer_playlists                      2445
# in_deezer_charts                            1
# in_shazam_charts                          140
# bpm                                       186
# key                                         G
# mode                                    Major
# danceability_%                             68
# valence_%                                  49
# energy_%                                   59
# ...

# %%
row_index = 48
col_index = 11

cell_value = df.iloc[row_index, col_index]
print(f"Value at row {row_index}, column {col_index}: {cell_value}")
# Out:
# Value at row 48, column 11: 2445

# %%
column_list = list(df['in_deezer_playlists'])
print(column_list)
# Out:
# [45, 58, 91, 125, 87, 88, 43, 30, 48, 66, 54, 21, 745, 182, 863, 161, 78, 95, 54, 23, 10, 42, 582, 32, 87, 10, 318, 41, 15, 143, 50, 13, 245, 165, 184, 34, 24, 410, 151, 15, 6, 843, 537, 247, 65, 138, 458, 24, 2445, 74, 57, 213, 23, 109, 3394, 3421, 57, 161, 39, 142, 73, 102, 4, 182, 89, 4053, 32, 169, 31, 8, 58, 707, 109, 1056, 164, 4095, 68, 331, 80, 18, 1003, 71, 25, 5, 798, 110, 1800, 141, 2703, 8, 35, 24, 29, 0, 8, 69, 63, 42, 1632, 25, 163, 19, 59, 2394, 4, 6,
54', '57', '22', '128', '24', '20', '33', '50', '15', '18', '12', '36', '78', '9', '16', '195', '3', '1,315', '124', '4', '6', '248', '65', '177', '84', '11', '274', '113', '15', '67', '23', '107', '25', '13', '7,827', '805', '8', '6', '0', '13', '2', '24', '328', '9', '13', '9', '119', '15', '158', '80', '13', '31', '13', '12', '30', '15', '17', '16', '12', '7', '13', '17', '15', '10', '13', '8', '7', '3', '15', '2', '5', '11', '37', '8', '7', '17', '32']
values_without_commas = [value.replace(',', '') for value in values_with_commas]
print(values_without_commas)
# Out:
# ['45', '58', '91', '125', '87', '88', '43', '30', '48', '66', '54', '21', '745', '182', '863', '161', '78', '95', '54', '23', '10', '42', '582', '32', '87', '10', '318', '41', '15', '143', '50', '13', '245', '165', '184', '34', '24', '410', '151', '15', '6', '843', '537', '247', '65', '138', '458', '24', '2445', '74', '57', '213', '23', '109', '3394', '3421', '57', '161', '39', '142', '73', '102', '4', '182', '89', '4053', '32', '169', '31', '8', '58', '707', '109', '1056', '164', '4095', '68', '331', '80', '18', '1003', '71', '25', '5', '798', '110', '1800', '141', '2703', '8', '35', '24', '29', '0', '8', '69', '63', '42', '1632', '25', '163', '19', '59', '2394', '4', '6', '1034', '59', '327', '2163', '695', '0', '4', '6', '2655', '476', '145', '24', '47', '61', '8', '246', '38', '21', '4', '52', '6551', '1212', '1078', '32', '7', '15', '282', '254', '588', '31', '30', '1', '2094', '50', '2969', '26', '30', '3889', '26', '5', '99', '5239', '44', '4', '3', '8', '974', '66', '356', '1
# ...

# %%
df['in_deezer_playlists'] = values_without_commas
print(df['in_deezer_playlists'])
# Out:
# 0       45
# 1       58
# 2       91
# 3      125
# 4       87
#       ...
# 948     37
# 949      8
# 950      7
# 951     17
# 952     32
# Name: in_deezer_playlists, Length: 953, dtype: object

# %%
#convertind data type of 'in_deezer_playlists', from object to intejer
df['in_deezer_playlists'] = pd.to_numeric(df['in_deezer_playlists'], errors='coerce').astype('Int64')
print(df.dtypes)
print("Completed fixing inconsistencies in the column 'in_deezer_playlists' ")
print("Completed fixing inconsistencies in the data types ")
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                  Int64
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists      Int64
# in_deezer_charts         int64
# in_shazam_charts         Int64
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object
# Completed fixing inconsistencies in the column 'in_deezer_playlists'
# Completed fixing inconsistencies in the data types

# %% [markdown]
# ### FINDING MISSING VALUES

# %%
#finding MISSING VALUES
missing_values = df.isnull()
missing_count = missing_values.sum()
print(missing_count)
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  1
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
#the columns: streams, in_shazam_charts & key contain missing values
#Fixing the missing values in streams
missing_values_count = df['streams'].isnull().sum()
print(missing_values_count)
row_with_missing_values = df[df['streams'].isnull()]
print(row_with_missing_values)
# Out:
# 1
#                               track_name     artist(s)_name  artist_count  \
# 574  Love Grows (Where My Rosemary Goes)  Edison Lighthouse             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 574           1970               1             1                  2877
#
#      in_spotify_charts  streams  in_apple_playlists  ...  bpm  key   mode  \
# 574                  0     <NA>                  16  ...  110    A  Major
#
#      danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 574              53         75       69              7                   0
#
#      liveness_%  speechiness_%
# 574          17              3
#
# [1 rows x 24 columns]

# %%
# replacing the <NA> value with the new value found on the spotify app (latest information)
row_index = 574  
column_name = 'streams'

new_value = 216264193
df.at[row_index, column_name] = 216264193


row_by_index = df.iloc[row_index]
print("Row 574:")
print(row_by_index)
# Out:
# Row 574:
# track_name              Love Grows (Where My Rosemary Goes)
# artist(s)_name                            Edison Lighthouse
# artist_count                                              1
# released_year                                          1970
# released_month                                            1
# released_day                                              1
# in_spotify_playlists                                   2877
# in_spotify_charts                                         0
# streams                                           216264193
# in_apple_playlists                                       16
# in_apple_charts                                           0
# in_deezer_playlists                                      54
# in_deezer_charts                                          0
# in_shazam_charts                                          0
# bpm                                                     110
# ...

# %%
#Fixing the missing values in in_shazam_charts
missing_values_count = df['in_shazam_charts'].isnull().sum()
print(missing_values_count)
rows_with_missing_values = df[df['in_shazam_charts'].isnull()]
print(rows_with_missing_values)
# Out:
# 50
#                                  track_name  \
# 14                                As It Was
# 54                             Another Love
# 55                          Blinding Lights
# 71                               Heat Waves
# 73                          Sweater Weather
# 86                        Someone You Loved
# 127                        Watermelon Sugar
# 158                                   Ghost
# 159                     Under The Influence
# 180                           Night Changes
# 243                             Unstoppable
# 274                                 Shivers
# 320                      Gangsta's Paradise
# 392                               Calm Down
# 395                              Space Song
# 403                One Kiss (with Dua Lipa)
# 410       INDUSTRY BABY (feat. Jack Harlow)
# 429                              Bad Habits
# 434                                   Woman
# 440                                Payphone
# ...

# %%
#replacing the missing values with the mean of the values
column_name = 'in_shazam_charts'
mean_value = df[column_name].mean()
df['in_shazam_charts'] = df['in_shazam_charts'].astype('float')
df[column_name].fillna(mean_value, inplace=True)
print('in_shazam_charts')

#Remaining missing values in in_shazam_charts
missing_values_count = df['in_shazam_charts'].isnull().sum()
print(missing_values_count)
rows_with_missing_values = df[df['in_shazam_charts'].isnull()]
print(rows_with_missing_values)
# Out:
# in_shazam_charts
# 0
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]

# %%
missing_values = df.isnull()
missing_count = missing_values.sum()
print(missing_count)
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts         0
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
#Fixing the missing values in key
#this is an object data type and is replaced with 'unknown'
df['key'].fillna('C', inplace=True)

missing_values_count = df['key'].isnull().sum()
print(missing_values_count)
rows_with_missing_values = df[df['key'].isnull()]
print(rows_with_missing_values)

print('Remaining missing values:')
missing_values = df.isnull()
missing_count = missing_values.sum()
print(missing_count)

print('Finished fixing missing values')
# Out:
# 0
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%]
# Index: []
#
# [0 rows x 24 columns]
# Remaining missing values:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# ...

# %%
row_by_index = df.iloc[row_index]
row_index = 60 
print("Row 60|:")
print(row_by_index)
# Out:
# Row 60|:
# track_name              Love Grows (Where My Rosemary Goes)
# artist(s)_name                            Edison Lighthouse
# artist_count                                              1
# released_year                                          1970
# released_month                                            1
# released_day                                              1
# in_spotify_playlists                                   2877
# in_spotify_charts                                         0
# streams                                           216264193
# in_apple_playlists                                       16
# in_apple_charts                                           0
# in_deezer_playlists                                      54
# in_deezer_charts                                          0
# in_shazam_charts                                        0.0
# bpm                                                     110
# ...

# %%
# Correcting the spelling mistake in a particular row
 #Value to search for in the 'track_name' column
value_to_search = 'Shawn Mendes, Camila Cabello'

# Print the row where the 'Name' column has the specified value
result_row = df.loc[df['artist(s)_name'] == value_to_search]

# Display the result
print(f"\nRow where 'artist(s)_name' is {value_to_search}:")
print(result_row)
row_index_to_correct = 693
column_to_correct = 'track_name'
corrected_value = 'Señorita'

df.at[row_index_to_correct, column_to_correct] = corrected_value
# Out:
# Row where 'artist(s)_name' is Shawn Mendes, Camila Cabello:
#     track_name                artist(s)_name  artist_count  released_year  \
# 693  Seï¿½ï¿½o  Shawn Mendes, Camila Cabello             2           2019
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 693               6            19                 15010                  2
#
#         streams  in_apple_playlists  ...  bpm  key   mode  danceability_%  \
# 693  2484812918                 453  ...  117    A  Minor              76
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 693         77       52              4                   0           8
#
#      speechiness_%
# 693              3
#
# [1 rows x 24 columns]

# %%
df.to_csv('final_2_spotify_updated_data.csv')

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
# Extract data from DataFrame

# Sort the DataFrame by the 'streams' column in descending order
df_sorted = df.sort_values(by='streams', ascending=False)

# Select the top 50 rows
top_100 = df_sorted.head(50)

# Extract data from the top 50 DataFrame
artists_top_100 = top_100['artist(s)_name']
streams_top_100 = top_100['streams']

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the bar graph for the top 50
ax.bar(artists_top_100, streams_top_100, color='skyblue')  # You can customize the color as needed

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90, ha='right')

# Add labels and title
ax.set_xlabel('Artists')
ax.set_ylabel('Streams')
ax.set_title('Top 50 Artists by Streams')

# Adjust layout for better presentation (optional)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Sort the DataFrame by the 'streams' column in descending order
df_sorted = df.sort_values(by='streams', ascending=False)

# Select the top 50 rows
top_100 = df_sorted.head(50)

# Extract data from the top 50 DataFrame
artists_top_100 = top_100['track_name']
streams_top_100 = top_100['streams']

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the bar graph for the top 50
ax.bar(artists_top_100, streams_top_100, color= 'red' ) # You can customize the color as needed

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90, ha='right')
plt.bar(x, y, width= 4 )
plt.subplots_adjust(bottom= 0.3)  # You can adjust this value based on your preference


# Add labels and title
ax.set_xlabel('Tracks')
ax.set_ylabel('Streams')
ax.set_title('Top 50 tracks by Streams')



# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 19
#      17 # Rotate x-axis labels for better visibility
#      18 plt.xticks(rotation=90, ha='right')
# ---> 19 plt.bar(x, y, width= 4 )
#      20 plt.subplots_adjust(bottom= 0.3)  # You can adjust this value based on your preference
#      23 # Add labels and title
#
# NameError: name 'x' is not defined
